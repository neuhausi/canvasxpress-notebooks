# %% [markdown]
# # Non-linear Scatter Plot with Line Decoration
#
# Scatter plot featuring non-linear fit decoration with lines included in data object, not configuration.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/scatter2d-10.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "scatter2d10",
    data = {
      "y": {
        "data": [
          [0.0009, 172],
          [0.0018, 177],
          [0.0037, 160],
          [0.0073, 166],
          [0.0146, 211],
          [0.0293, 248],
          [0.0586, 269],
          [0.117, 283],
          [0.234, 298],
          [0.469, 314],
          [0.938, 328],
          [1.88, 316]
        ],
        "smps": ["Concentration", "V1"],
        "vars": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10", "S11", "S12"]
      }
    },
    config = {
      "decorations": {
        "nlfit": [
          {
            "label": "Custom Fit",
            "param": [164, 313, 0.031, -1.5, 1.2e-06, 1.9],
            "type": "cst"
          },
          {
            "label": "Regular Fit",
            "param": [164, 313, 0.031, 1.5, 1.2e-06, 1.9],
            "type": "reg"
          }
        ]
      },
      "graphType": "Scatter2D",
      "setMaxY": 350,
      "setMinY": 100,
      "showDecorations": True,
      "xAxis": ["Concentration"],
      "xAxisTransform": "log10",
      "xAxisTransformTicks": True,
      "yAxis": ["V1"],
      "yAxisExact": True
    },
    width = 600,
    height = 600
  )
)
