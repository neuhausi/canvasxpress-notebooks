# %% [markdown]
# # Mastering Normal Distribution for Data Analysis
#
# Understand the intricacies of a normal distribution for comprehensive data analysis.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/nonlinear-fit-2.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "nonlinearfit2",
    data = {
      "y": {
        "data": [
          [0, 2],
          [1, 4],
          [2, 7],
          [3, 7],
          [4, 19],
          [5, 20],
          [6, 43],
          [7, 51],
          [8, 74],
          [9, 81],
          [10, 75],
          [11, 117],
          [12, 100],
          [13, 84],
          [14, 90],
          [15, 54],
          [16, 43],
          [17, 47],
          [18, 34],
          [19, 24],
          [20, 11],
          [21, 7],
          [22, 4],
          [23, 2]
        ],
        "smps": ["X", "Y"],
        "vars": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10", "S11", "S12", "S13", "S14", "S15", "S16", "S17", "S18", "S19", "S20", "S21", "S22", "S23", "S24"]
      }
    },
    config = {
      "graphType": "Scatter2D",
      "showDecorations": True,
      "showLegend": False,
      "xAxis": ["X"],
      "yAxis": ["Y"]
    },
    after_render = [
      [
        "addNormalDistributionLine",
        []
      ]
    ],
    width = 600,
    height = 600
  )
)
