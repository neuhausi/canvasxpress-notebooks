# %% [markdown]
# # Half Chord Graph: Relationship Visualization
#
# Explore relationships with a rotated half chord graph for clear and concise data visualization.
#
# Live example, data and R/JavaScript code: https://www.canvasxpress.org/examples/chord-3.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "chord3",
    data = {
      "y": {
        "data": [
          [11975, 5871, 8916, 2868],
          [1951, 10048, 2060, 6171],
          [8010, 16145, 8090, 8045],
          [1013, 990, 940, 6907]
        ],
        "smps": ["A", "B", "C", "D"],
        "vars": ["A", "B", "C", "D"]
      }
    },
    config = {
      "circularArc": 180,
      "circularRotate": -90,
      "circularType": "chord",
      "graphType": "Circular",
      "higlightGreyOut": True,
      "legendKeyBackgroundBorderColor": "rgba(255,255,255,0)",
      "legendKeyBackgroundColor": "rgba(255,255,255,0)",
      "objectBorderColor": "rgb(0,0,0)",
      "rAxisTickFormat": ["%sK", " / 1000"],
      "showLegend": False,
      "showTransition": False,
      "title": "Rotated Half Chord Graph",
      "transitionStep": 50,
      "transitionTime": 1500
    },
    width = 600,
    height = 600
  )
)
