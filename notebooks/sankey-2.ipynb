# %% [markdown]
# # Colorful Sankey Diagram for Category Flow
#
# A single-level colored Sankey diagram visually represents flow magnitudes between categories in a clear and concise manner.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/sankey-2.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "sankey2",
    data = {
      "x": {
        "Source": ["A", "A", "A", "B", "B", "B"],
        "Target": ["X", "Y", "Z", "X", "Y", "Z"],
        "Weight": [1, 2, 3, 4, 5, 6]
      },
      "y": {
        "data": [
          [5, 7, 6, 2, 9, 4]
        ],
        "smps": ["smp1", "smp2", "smp3", "smp4", "smp5", "smp6"],
        "vars": ["Weight"]
      }
    },
    config = {
      "colorBy": "Weight",
      "graphOrientation": "vertical",
      "graphType": "Sankey",
      "sankeySource": "Source",
      "sankeyTarget": "Target",
      "title": "Single Level Sankey",
      "xAxis": ["Weight"]
    },
    width = 600,
    height = 600
  )
)
