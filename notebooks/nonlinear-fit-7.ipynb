# %% [markdown]
# # Master Nonlinear Regression Analysis
#
# Explore the nuances of nonlinear regression for deeper insights.
#
# Live example, data and R/JavaScript code: https://www.canvasxpress.org/examples/nonlinear-fit-7.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "nonlinearfit7",
    data = {
      "y": {
        "data": [
          [4, 390],
          [9, 580],
          [10, 650],
          [14, 730],
          [4, 410],
          [7, 530],
          [12, 600],
          [22, 790],
          [1, 350],
          [3, 400],
          [8, 590],
          [11, 640],
          [5, 450],
          [6, 520],
          [10, 690],
          [11, 690],
          [16, 770],
          [13, 700],
          [13, 730],
          [10, 640]
        ],
        "smps": ["Hours", "Score"],
        "vars": ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10", "S11", "S12", "S13", "S14", "S15", "S16", "S17", "S18", "S19", "S20"]
      }
    },
    config = {
      "decorations": {
        "linear": [
          {
            "color": "red"
          }
        ]
      },
      "graphType": "Scatter2D",
      "showDecorations": True,
      "showLegend": False,
      "xAxis": ["Hours"],
      "yAxis": ["Score"]
    },
    width = 600,
    height = 600
  )
)
