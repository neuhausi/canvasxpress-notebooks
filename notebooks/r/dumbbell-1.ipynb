# %% [markdown]
# # Dumbbell Chart: Visualize Change
#
# Dumbbell graphs visualize change between two data points highlighting shifts and variations across categories efficiently.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/dumbbell-1.html
#
# Requires the `canvasXpress` R package (`install.packages("canvasXpress")`, preinstalled on Binder).

# %%
library(canvasXpress)
y=read.table("https://www.canvasxpress.org/data/r/cX-dumbbell2-dat.txt", header=TRUE, sep="\t", quote="", row.names=1, fill=TRUE, check.names=FALSE, stringsAsFactors=FALSE)
canvasXpress(
data=y,
colors=list("grey", "blue", "pink"),
graphType="Dumbbell",
legendColumns=2,
legendPosition="bottom",
sortDir="ascending",
title="Age Range by Gender",
xAxis=list("Female", "Male"),
xAxis2Show=TRUE,
xAxisShow=FALSE,
xAxisTitle2="Age"
)
