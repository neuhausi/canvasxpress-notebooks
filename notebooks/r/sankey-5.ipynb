# %% [markdown]
# # Visualize Data Flows with Alluvial Plots
#
# Alluvial plots are effective tools for visualizing multi-dimensional categorical data flows, offering insights into complex relationships with intuitive clarity.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/sankey-5.html
#
# Requires the `canvasXpress` R package (`install.packages("canvasXpress")`, preinstalled on Binder).

# %%
library(canvasXpress)
y=read.table("https://www.canvasxpress.org/data/r/cX-titanicR-dat.txt", header=TRUE, sep="\t", quote="", row.names=1, fill=TRUE, check.names=FALSE, stringsAsFactors=FALSE)
x=read.table("https://www.canvasxpress.org/data/r/cX-titanicR-smp.txt", header=TRUE, sep="\t", quote="", row.names=1, fill=TRUE, check.names=FALSE, stringsAsFactors=FALSE)
canvasXpress(
data=y,
smpAnnot=x,
colorBy="Survived",
colorScheme="GGPlot",
graphOrientation="horizontal",
graphType="Sankey",
sankeyAxes=list("Class", "Sex", "Age", "Survived"),
sankeyNodesColor="rgb(255,255,255)",
scheme="GGPlot",
title="Alluvial Plot",
xAxis=list("Freq")
)
