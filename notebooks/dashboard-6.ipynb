# %% [markdown]
# # DOE Mapping Dashboard: Interactive Data Analysis & Visualization
#
# Dynamic DOE mapping dashboard for interactive data analysis and visualization.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/dashboard-6.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "dashboard6",
    data = {
      "y": {
        "data": [
          [None, 92.7, 68.7],
          [2.4, 90.6, 64.5],
          [None, 91.7, 70],
          [None, 91.7, 60.6],
          [None, 92.2, 71.3],
          [None, 89.9, 63],
          [None, 94.4, 58.5],
          [1.8, 92.2, 69],
          [3.2, 90.3, 65.8],
          [None, 93.3, 58.1],
          [0.9, 90.6, 67.4],
          [None, 90.6, 63],
          [None, 85.4, 53],
          [3, 91.4, 59.5],
          [1.2, 93.4, 64],
          [None, 90.4, 65.8],
          [None, 90.6, 58],
          [None, 88.7, 62.4],
          [1.6, 90.9, 64.5],
          [1.7, 90.9, 65.3],
          [None, 94.4, 68.4],
          [None, 90, 65.3],
          [None, 88.8, 67.9],
          [2.2, 91, 60.9],
          [1.8, 91.3, 66.2],
          [None, 92.4, 62.2],
          [None, 87.5, 54],
          [3, 86.8, 63.5],
          [None, None, None],
          [None, None, None],
          [None, None, None],
          [None, 92.9, 69.8],
          [1.7, 91.1, 63.6],
          [1, 92.1, 66.6],
          [1.2, 88.9, 67.5],
          [None, 91.7, 67.2],
          [0.6, 94.5, 70.1],
          [0.5, 94, 65.5],
          [0.8, 94.8, 68.3],
          [0.9, 94, 66.7],
          [1.2, 92.9, 66],
          [0.5, 92.9, 65.4],
          [0.8, 92.9, 67.3],
          [0.5, 94.1, 67.1],
          [0.4, 92.8, 64.3],
          [0.3, 95.5, 69.5],
          [0.4, 95.9, 71.1],
          [None, 91.3, 67.9],
          [0.5, 95.4, 69.1],
          [None, 94.3, 71.4],
          [None, 92.2, 66.6],
          [0.4, 95.3, 69],
          [0.7, 93.7, 65.7],
          [0.7, 95.3, 67.2],
          [1.7, 90.3, 63.2],
          [1.1, 92.7, 67.8],
          [None, None, None],
          [None, None, None],
          [0.6, 94.6, 69.2],
          [0.8, 94.9, 68.6],
          [0.7, 95.4, 67.5],
          [None, 95.7, 67],
          [1.1, 93.4, 65.9],
          [None, 93.3, 59.5],
          [1.2, 94.6, 64.3],
          [0.9, 94.8, 67.1],
          [0.5, 95.2, 65.6],
          [0.6, 92.7, 67.6],
          [1.8, 94.3, 66.5],
          [0.8, 93.9, 65.9],
          [None, None, None],
          [None, None, None],
          [None, None, None],
          [None, 72.9, None],
          [None, None, None],
          [None, None, None],
          [4.2, 86.7, 63.5],
          [None, 92.5, 66.9],
          [None, None, None],
          [None, None, None],
          [None, None, None],
          [None, None, None],
          [2.5, 87.6, 66.2],
          [None, None, None],
          [None, None, None],
          [2, 90.2, 65],
          [5.8, 81, 59.5],
          [7.9, 79.3, 59.5],
          [None, None, None]
        ],
        "smps": ["No Preventive Actions", "Physical Distancing", "Stay Home Sick"],
        "vars": ["111", "112", "113", "114", "115", "116", "121", "122", "123", "124", "125", "126", "127", "131", "132", "133", "134", "135", "136", "137", "138", "139", "141", "142", "143", "144", "145", "146", "147", "148", "149", "211", "212", "213", "214", "215", "221", "222", "223", "224", "231", "232", "233", "234", "311", "321", "322", "323", "324", "325", "326", "331", "332", "333", "334", "335", "336", "337", "411", "412", "413", "414", "421", "422", "423", "424", "425", "426", "431", "432", "433", "434", "510", "511", "512", "513", "514", "515", "516", "517", "518", "519", "521", "522", "523", "524", "531", "532", "533"]
      }
    },
    config = {
      "asDOE": True,
      "colorBy": "Stay Home Sick",
      "graphType": "Map",
      "histogramBins": False,
      "layoutConfig": [
        {
          "size": "2X2"
        }
      ],
      "legendPosition": "top",
      "mapId": "bc",
      "mapPropertyId": "LOCAL_HLTH_AREA_CODE",
      "topoJSON": "https://www.canvasxpress.org/data/json/bc.json",
      "xAxis": ["No Preventive Actions", "Physical Distancing", "Stay Home Sick"]
    },
    width = 600,
    height = 600
  )
)
