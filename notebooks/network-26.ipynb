# %% [markdown]
# # CodeFlower: Visualize Source Code Connections
#
# Visualize source code connections with CodeFlower to understand project structure.
#
# Live example, data and code in other languages: https://www.canvasxpress.org/examples/network-26.html
#
# Requires `pip install "canvasxpress[jupyter]"` (preinstalled on Binder).

# %%
from canvasxpress.canvas import CanvasXpress
from canvasxpress.plot import graph

graph(
  CanvasXpress(
    render_to = "network26",
    data = {
      "edges": [
        {
          "id1": "Id0",
          "id2": "Id1"
        },
        {
          "id1": "Id1",
          "id2": "Id2"
        },
        {
          "id1": "Id2",
          "id2": "Id3"
        },
        {
          "id1": "Id3",
          "id2": "Id4"
        },
        {
          "id1": "Id4",
          "id2": "Id5"
        },
        {
          "id1": "Id4",
          "id2": "Id6"
        },
        {
          "id1": "Id4",
          "id2": "Id7"
        },
        {
          "id1": "Id4",
          "id2": "Id8"
        },
        {
          "id1": "Id4",
          "id2": "Id9"
        },
        {
          "id1": "Id3",
          "id2": "Id10"
        },
        {
          "id1": "Id10",
          "id2": "Id11"
        },
        {
          "id1": "Id10",
          "id2": "Id12"
        },
        {
          "id1": "Id10",
          "id2": "Id13"
        },
        {
          "id1": "Id10",
          "id2": "Id14"
        },
        {
          "id1": "Id10",
          "id2": "Id15"
        },
        {
          "id1": "Id10",
          "id2": "Id16"
        },
        {
          "id1": "Id3",
          "id2": "Id17"
        },
        {
          "id1": "Id17",
          "id2": "Id18"
        },
        {
          "id1": "Id17",
          "id2": "Id19"
        },
        {
          "id1": "Id17",
          "id2": "Id20"
        },
        {
          "id1": "Id17",
          "id2": "Id21"
        },
        {
          "id1": "Id17",
          "id2": "Id22"
        },
        {
          "id1": "Id3",
          "id2": "Id23"
        },
        {
          "id1": "Id23",
          "id2": "Id24"
        },
        {
          "id1": "Id23",
          "id2": "Id25"
        },
        {
          "id1": "Id23",
          "id2": "Id26"
        },
        {
          "id1": "Id23",
          "id2": "Id27"
        },
        {
          "id1": "Id23",
          "id2": "Id28"
        },
        {
          "id1": "Id3",
          "id2": "Id29"
        },
        {
          "id1": "Id29",
          "id2": "Id30"
        },
        {
          "id1": "Id29",
          "id2": "Id31"
        },
        {
          "id1": "Id3",
          "id2": "Id32"
        },
        {
          "id1": "Id3",
          "id2": "Id33"
        },
        {
          "id1": "Id33",
          "id2": "Id34"
        },
        {
          "id1": "Id33",
          "id2": "Id35"
        },
        {
          "id1": "Id33",
          "id2": "Id36"
        },
        {
          "id1": "Id33",
          "id2": "Id37"
        },
        {
          "id1": "Id3",
          "id2": "Id38"
        },
        {
          "id1": "Id38",
          "id2": "Id39"
        },
        {
          "id1": "Id38",
          "id2": "Id40"
        },
        {
          "id1": "Id38",
          "id2": "Id41"
        },
        {
          "id1": "Id38",
          "id2": "Id42"
        },
        {
          "id1": "Id38",
          "id2": "Id43"
        },
        {
          "id1": "Id3",
          "id2": "Id44"
        },
        {
          "id1": "Id44",
          "id2": "Id45"
        },
        {
          "id1": "Id44",
          "id2": "Id46"
        },
        {
          "id1": "Id44",
          "id2": "Id47"
        },
        {
          "id1": "Id44",
          "id2": "Id48"
        },
        {
          "id1": "Id3",
          "id2": "Id49"
        },
        {
          "id1": "Id49",
          "id2": "Id50"
        },
        {
          "id1": "Id49",
          "id2": "Id51"
        },
        {
          "id1": "Id49",
          "id2": "Id52"
        },
        {
          "id1": "Id3",
          "id2": "Id53"
        },
        {
          "id1": "Id53",
          "id2": "Id54"
        },
        {
          "id1": "Id53",
          "id2": "Id55"
        },
        {
          "id1": "Id53",
          "id2": "Id56"
        },
        {
          "id1": "Id53",
          "id2": "Id57"
        },
        {
          "id1": "Id53",
          "id2": "Id58"
        },
        {
          "id1": "Id3",
          "id2": "Id59"
        },
        {
          "id1": "Id3",
          "id2": "Id60"
        },
        {
          "id1": "Id3",
          "id2": "Id61"
        },
        {
          "id1": "Id3",
          "id2": "Id62"
        },
        {
          "id1": "Id62",
          "id2": "Id63"
        },
        {
          "id1": "Id62",
          "id2": "Id64"
        },
        {
          "id1": "Id62",
          "id2": "Id65"
        },
        {
          "id1": "Id3",
          "id2": "Id66"
        },
        {
          "id1": "Id66",
          "id2": "Id67"
        },
        {
          "id1": "Id66",
          "id2": "Id68"
        },
        {
          "id1": "Id66",
          "id2": "Id69"
        },
        {
          "id1": "Id66",
          "id2": "Id70"
        },
        {
          "id1": "Id66",
          "id2": "Id71"
        },
        {
          "id1": "Id3",
          "id2": "Id72"
        },
        {
          "id1": "Id72",
          "id2": "Id73"
        },
        {
          "id1": "Id72",
          "id2": "Id74"
        },
        {
          "id1": "Id72",
          "id2": "Id75"
        },
        {
          "id1": "Id72",
          "id2": "Id76"
        },
        {
          "id1": "Id72",
          "id2": "Id77"
        },
        {
          "id1": "Id3",
          "id2": "Id78"
        },
        {
          "id1": "Id78",
          "id2": "Id79"
        },
        {
          "id1": "Id78",
          "id2": "Id80"
        },
        {
          "id1": "Id78",
          "id2": "Id81"
        },
        {
          "id1": "Id78",
          "id2": "Id82"
        },
        {
          "id1": "Id3",
          "id2": "Id83"
        },
        {
          "id1": "Id83",
          "id2": "Id84"
        },
        {
          "id1": "Id83",
          "id2": "Id85"
        },
        {
          "id1": "Id83",
          "id2": "Id86"
        },
        {
          "id1": "Id83",
          "id2": "Id87"
        },
        {
          "id1": "Id3",
          "id2": "Id88"
        },
        {
          "id1": "Id3",
          "id2": "Id89"
        },
        {
          "id1": "Id89",
          "id2": "Id90"
        },
        {
          "id1": "Id89",
          "id2": "Id91"
        },
        {
          "id1": "Id89",
          "id2": "Id92"
        },
        {
          "id1": "Id89",
          "id2": "Id93"
        },
        {
          "id1": "Id3",
          "id2": "Id94"
        },
        {
          "id1": "Id94",
          "id2": "Id95"
        },
        {
          "id1": "Id94",
          "id2": "Id96"
        },
        {
          "id1": "Id94",
          "id2": "Id97"
        },
        {
          "id1": "Id3",
          "id2": "Id98"
        },
        {
          "id1": "Id98",
          "id2": "Id99"
        },
        {
          "id1": "Id98",
          "id2": "Id100"
        },
        {
          "id1": "Id98",
          "id2": "Id101"
        },
        {
          "id1": "Id98",
          "id2": "Id102"
        },
        {
          "id1": "Id98",
          "id2": "Id103"
        },
        {
          "id1": "Id3",
          "id2": "Id104"
        },
        {
          "id1": "Id3",
          "id2": "Id105"
        },
        {
          "id1": "Id105",
          "id2": "Id106"
        },
        {
          "id1": "Id105",
          "id2": "Id107"
        },
        {
          "id1": "Id105",
          "id2": "Id108"
        },
        {
          "id1": "Id3",
          "id2": "Id109"
        },
        {
          "id1": "Id109",
          "id2": "Id110"
        },
        {
          "id1": "Id109",
          "id2": "Id111"
        },
        {
          "id1": "Id3",
          "id2": "Id112"
        },
        {
          "id1": "Id112",
          "id2": "Id113"
        },
        {
          "id1": "Id112",
          "id2": "Id114"
        },
        {
          "id1": "Id3",
          "id2": "Id115"
        },
        {
          "id1": "Id115",
          "id2": "Id116"
        },
        {
          "id1": "Id115",
          "id2": "Id117"
        },
        {
          "id1": "Id3",
          "id2": "Id118"
        },
        {
          "id1": "Id3",
          "id2": "Id119"
        },
        {
          "id1": "Id119",
          "id2": "Id120"
        },
        {
          "id1": "Id119",
          "id2": "Id121"
        },
        {
          "id1": "Id119",
          "id2": "Id122"
        },
        {
          "id1": "Id3",
          "id2": "Id123"
        },
        {
          "id1": "Id3",
          "id2": "Id124"
        },
        {
          "id1": "Id3",
          "id2": "Id125"
        },
        {
          "id1": "Id3",
          "id2": "Id126"
        },
        {
          "id1": "Id2",
          "id2": "Id127"
        },
        {
          "id1": "Id127",
          "id2": "Id128"
        },
        {
          "id1": "Id128",
          "id2": "Id129"
        },
        {
          "id1": "Id128",
          "id2": "Id130"
        },
        {
          "id1": "Id128",
          "id2": "Id131"
        },
        {
          "id1": "Id127",
          "id2": "Id132"
        },
        {
          "id1": "Id132",
          "id2": "Id133"
        },
        {
          "id1": "Id132",
          "id2": "Id134"
        },
        {
          "id1": "Id132",
          "id2": "Id135"
        },
        {
          "id1": "Id127",
          "id2": "Id136"
        },
        {
          "id1": "Id136",
          "id2": "Id137"
        },
        {
          "id1": "Id136",
          "id2": "Id138"
        },
        {
          "id1": "Id136",
          "id2": "Id139"
        },
        {
          "id1": "Id2",
          "id2": "Id140"
        },
        {
          "id1": "Id140",
          "id2": "Id141"
        },
        {
          "id1": "Id2",
          "id2": "Id142"
        },
        {
          "id1": "Id2",
          "id2": "Id143"
        },
        {
          "id1": "Id2",
          "id2": "Id144"
        },
        {
          "id1": "Id1",
          "id2": "Id145"
        },
        {
          "id1": "Id0",
          "id2": "Id146"
        },
        {
          "id1": "Id146",
          "id2": "Id147"
        },
        {
          "id1": "Id147",
          "id2": "Id148"
        },
        {
          "id1": "Id147",
          "id2": "Id149"
        },
        {
          "id1": "Id149",
          "id2": "Id150"
        },
        {
          "id1": "Id149",
          "id2": "Id151"
        },
        {
          "id1": "Id149",
          "id2": "Id152"
        },
        {
          "id1": "Id152",
          "id2": "Id153"
        },
        {
          "id1": "Id149",
          "id2": "Id154"
        },
        {
          "id1": "Id149",
          "id2": "Id155"
        },
        {
          "id1": "Id149",
          "id2": "Id156"
        },
        {
          "id1": "Id149",
          "id2": "Id157"
        },
        {
          "id1": "Id147",
          "id2": "Id158"
        },
        {
          "id1": "Id158",
          "id2": "Id159"
        },
        {
          "id1": "Id159",
          "id2": "Id160"
        },
        {
          "id1": "Id160",
          "id2": "Id161"
        },
        {
          "id1": "Id160",
          "id2": "Id162"
        },
        {
          "id1": "Id160",
          "id2": "Id163"
        },
        {
          "id1": "Id146",
          "id2": "Id164"
        },
        {
          "id1": "Id146",
          "id2": "Id165"
        },
        {
          "id1": "Id0",
          "id2": "Id166"
        }
      ],
      "nodes": [
        {
          "color": "rgb(247,114,109)",
          "height": "14.0",
          "id": "Id0",
          "name": "root",
          "width": "14.0"
        },
        {
          "color": "rgb(247,118,109)",
          "height": "14.0",
          "id": "Id1",
          "name": "src",
          "width": "14.0"
        },
        {
          "color": "rgb(247,123,109)",
          "height": "14.0",
          "id": "Id2",
          "name": "Faker",
          "width": "14.0"
        },
        {
          "color": "rgb(247,128,109)",
          "height": "14.0",
          "id": "Id3",
          "name": "Provider",
          "width": "14.0"
        },
        {
          "color": "rgb(247,132,109)",
          "height": "14.0",
          "id": "Id4",
          "name": "sk_SK",
          "width": "14.0"
        },
        {
          "color": "rgb(247,137,109)",
          "height": "41.0",
          "id": "Id5",
          "language": "PHP",
          "name": "Address.php",
          "width": "41.0"
        },
        {
          "color": "rgb(247,144,109)",
          "height": "27.9",
          "id": "Id6",
          "language": "PHP",
          "name": "Person.php",
          "width": "27.9"
        },
        {
          "color": "rgb(247,148,109)",
          "height": "19.0",
          "id": "Id7",
          "language": "PHP",
          "name": "Company.php",
          "width": "19.0"
        },
        {
          "color": "rgb(247,153,109)",
          "height": "13.8",
          "id": "Id8",
          "language": "PHP",
          "name": "Internet.php",
          "width": "13.8"
        },
        {
          "color": "rgb(247,157,109)",
          "height": "11.2",
          "id": "Id9",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "11.2"
        },
        {
          "color": "rgb(247,162,109)",
          "height": "14.0",
          "id": "Id10",
          "name": "ua_UA",
          "width": "14.0"
        },
        {
          "color": "rgb(247,167,109)",
          "height": "40.1",
          "id": "Id11",
          "language": "PHP",
          "name": "Address.php",
          "width": "40.1"
        },
        {
          "color": "rgb(247,173,109)",
          "height": "18.7",
          "id": "Id12",
          "language": "PHP",
          "name": "Transliteration.php",
          "width": "18.7"
        },
        {
          "color": "rgb(247,178,109)",
          "height": "17.3",
          "id": "Id13",
          "language": "PHP",
          "name": "Person.php",
          "width": "17.3"
        },
        {
          "color": "rgb(247,183,109)",
          "height": "16.6",
          "id": "Id14",
          "language": "PHP",
          "name": "Company.php",
          "width": "16.6"
        },
        {
          "color": "rgb(247,187,109)",
          "height": "13.8",
          "id": "Id15",
          "language": "PHP",
          "name": "Internet.php",
          "width": "13.8"
        },
        {
          "color": "rgb(247,192,109)",
          "height": "13.8",
          "id": "Id16",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "13.8"
        },
        {
          "color": "rgb(247,196,109)",
          "height": "14.0",
          "id": "Id17",
          "name": "da_DK",
          "width": "14.0"
        },
        {
          "color": "rgb(247,201,109)",
          "height": "31.9",
          "id": "Id18",
          "language": "PHP",
          "name": "Address.php",
          "width": "31.9"
        },
        {
          "color": "rgb(247,208,109)",
          "height": "29.3",
          "id": "Id19",
          "language": "PHP",
          "name": "Person.php",
          "width": "29.3"
        },
        {
          "color": "rgb(247,212,109)",
          "height": "16.4",
          "id": "Id20",
          "language": "PHP",
          "name": "Company.php",
          "width": "16.4"
        },
        {
          "color": "rgb(247,217,109)",
          "height": "16.2",
          "id": "Id21",
          "language": "PHP",
          "name": "Internet.php",
          "width": "16.2"
        },
        {
          "color": "rgb(247,222,109)",
          "height": "11.2",
          "id": "Id22",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "11.2"
        },
        {
          "color": "rgb(247,226,109)",
          "height": "14.0",
          "id": "Id23",
          "name": "de_DE",
          "width": "14.0"
        },
        {
          "color": "rgb(247,231,109)",
          "height": "31.4",
          "id": "Id24",
          "language": "PHP",
          "name": "Person.php",
          "width": "31.4"
        },
        {
          "color": "rgb(247,238,109)",
          "height": "22.3",
          "id": "Id25",
          "language": "PHP",
          "name": "Address.php",
          "width": "22.3"
        },
        {
          "color": "rgb(247,242,109)",
          "height": "14.9",
          "id": "Id26",
          "language": "PHP",
          "name": "Internet.php",
          "width": "14.9"
        },
        {
          "color": "rgb(247,247,109)",
          "height": "12.7",
          "id": "Id27",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "12.7"
        },
        {
          "color": "rgb(242,247,109)",
          "height": "10.8",
          "id": "Id28",
          "language": "PHP",
          "name": "Company.php",
          "width": "10.8"
        },
        {
          "color": "rgb(238,247,109)",
          "height": "14.0",
          "id": "Id29",
          "name": "de_AT",
          "width": "14.0"
        },
        {
          "color": "rgb(233,247,109)",
          "height": "31.2",
          "id": "Id30",
          "language": "PHP",
          "name": "Person.php",
          "width": "31.2"
        },
        {
          "color": "rgb(228,247,109)",
          "height": "23.9",
          "id": "Id31",
          "language": "PHP",
          "name": "Address.php",
          "width": "23.9"
        },
        {
          "color": "rgb(222,247,109)",
          "height": "28.7",
          "id": "Id32",
          "language": "PHP",
          "name": "Lorem.php",
          "width": "28.7"
        },
        {
          "color": "rgb(217,247,109)",
          "height": "14.0",
          "id": "Id33",
          "name": "ru_RU",
          "width": "14.0"
        },
        {
          "color": "rgb(212,247,109)",
          "height": "28.2",
          "id": "Id34",
          "language": "PHP",
          "name": "Address.php",
          "width": "28.2"
        },
        {
          "color": "rgb(208,247,109)",
          "height": "22.4",
          "id": "Id35",
          "language": "PHP",
          "name": "Person.php",
          "width": "22.4"
        },
        {
          "color": "rgb(203,247,109)",
          "height": "13.0",
          "id": "Id36",
          "language": "PHP",
          "name": "Internet.php",
          "width": "13.0"
        },
        {
          "color": "rgb(199,247,109)",
          "height": "10.8",
          "id": "Id37",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "10.8"
        },
        {
          "color": "rgb(192,247,109)",
          "height": "14.0",
          "id": "Id38",
          "name": "fr_FR",
          "width": "14.0"
        },
        {
          "color": "rgb(187,247,109)",
          "height": "26.9",
          "id": "Id39",
          "language": "PHP",
          "name": "Company.php",
          "width": "26.9"
        },
        {
          "color": "rgb(183,247,109)",
          "height": "24.5",
          "id": "Id40",
          "language": "PHP",
          "name": "Address.php",
          "width": "24.5"
        },
        {
          "color": "rgb(178,247,109)",
          "height": "17.3",
          "id": "Id41",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "17.3"
        },
        {
          "color": "rgb(173,247,109)",
          "height": "15.6",
          "id": "Id42",
          "language": "PHP",
          "name": "Person.php",
          "width": "15.6"
        },
        {
          "color": "rgb(169,247,109)",
          "height": "14.9",
          "id": "Id43",
          "language": "PHP",
          "name": "Internet.php",
          "width": "14.9"
        },
        {
          "color": "rgb(162,247,109)",
          "height": "14.0",
          "id": "Id44",
          "name": "pt_BR",
          "width": "14.0"
        },
        {
          "color": "rgb(157,247,109)",
          "height": "26.2",
          "id": "Id45",
          "language": "PHP",
          "name": "Address.php",
          "width": "26.2"
        },
        {
          "color": "rgb(153,247,109)",
          "height": "24.0",
          "id": "Id46",
          "language": "PHP",
          "name": "Person.php",
          "width": "24.0"
        },
        {
          "color": "rgb(148,247,109)",
          "height": "19.3",
          "id": "Id47",
          "language": "PHP",
          "name": "Company.php",
          "width": "19.3"
        },
        {
          "color": "rgb(144,247,109)",
          "height": "15.4",
          "id": "Id48",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "15.4"
        },
        {
          "color": "rgb(139,247,109)",
          "height": "14.0",
          "id": "Id49",
          "name": "bg_BG",
          "width": "14.0"
        },
        {
          "color": "rgb(134,247,109)",
          "height": "25.9",
          "id": "Id50",
          "language": "PHP",
          "name": "Person.php",
          "width": "25.9"
        },
        {
          "color": "rgb(128,247,109)",
          "height": "13.5",
          "id": "Id51",
          "language": "PHP",
          "name": "Internet.php",
          "width": "13.5"
        },
        {
          "color": "rgb(123,247,109)",
          "height": "12.7",
          "id": "Id52",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "12.7"
        },
        {
          "color": "rgb(118,247,109)",
          "height": "14.0",
          "id": "Id53",
          "name": "nl_NL",
          "width": "14.0"
        },
        {
          "color": "rgb(114,247,109)",
          "height": "23.9",
          "id": "Id54",
          "language": "PHP",
          "name": "Person.php",
          "width": "23.9"
        },
        {
          "color": "rgb(109,247,109)",
          "height": "23.4",
          "id": "Id55",
          "language": "PHP",
          "name": "Address.php",
          "width": "23.4"
        },
        {
          "color": "rgb(109,247,114)",
          "height": "16.0",
          "id": "Id56",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "16.0"
        },
        {
          "color": "rgb(109,247,121)",
          "height": "10.8",
          "id": "Id57",
          "language": "PHP",
          "name": "Company.php",
          "width": "10.8"
        },
        {
          "color": "rgb(109,247,125)",
          "height": "9.2",
          "id": "Id58",
          "language": "PHP",
          "name": "Internet.php",
          "width": "9.2"
        },
        {
          "color": "rgb(109,247,130)",
          "height": "23.8",
          "id": "Id59",
          "language": "PHP",
          "name": "UserAgent.php",
          "width": "23.8"
        },
        {
          "color": "rgb(109,247,134)",
          "height": "23.6",
          "id": "Id60",
          "language": "PHP",
          "name": "DateTime.php",
          "width": "23.6"
        },
        {
          "color": "rgb(109,247,139)",
          "height": "23.6",
          "id": "Id61",
          "language": "PHP",
          "name": "Internet.php",
          "width": "23.6"
        },
        {
          "color": "rgb(109,247,144)",
          "height": "14.0",
          "id": "Id62",
          "name": "cs_CZ",
          "width": "14.0"
        },
        {
          "color": "rgb(109,247,148)",
          "height": "23.4",
          "id": "Id63",
          "language": "PHP",
          "name": "Person.php",
          "width": "23.4"
        },
        {
          "color": "rgb(109,247,155)",
          "height": "13.8",
          "id": "Id64",
          "language": "PHP",
          "name": "Internet.php",
          "width": "13.8"
        },
        {
          "color": "rgb(109,247,160)",
          "height": "10.8",
          "id": "Id65",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "10.8"
        },
        {
          "color": "rgb(109,247,164)",
          "height": "14.0",
          "id": "Id66",
          "name": "nl_BE",
          "width": "14.0"
        },
        {
          "color": "rgb(109,247,169)",
          "height": "23.3",
          "id": "Id67",
          "language": "PHP",
          "name": "Address.php",
          "width": "23.3"
        },
        {
          "color": "rgb(109,247,173)",
          "height": "14.9",
          "id": "Id68",
          "language": "PHP",
          "name": "Internet.php",
          "width": "14.9"
        },
        {
          "color": "rgb(109,247,178)",
          "height": "12.7",
          "id": "Id69",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "12.7"
        },
        {
          "color": "rgb(109,247,185)",
          "height": "10.4",
          "id": "Id70",
          "language": "PHP",
          "name": "Person.php",
          "width": "10.4"
        },
        {
          "color": "rgb(109,247,189)",
          "height": "10.0",
          "id": "Id71",
          "language": "PHP",
          "name": "Company.php",
          "width": "10.0"
        },
        {
          "color": "rgb(109,247,194)",
          "height": "14.0",
          "id": "Id72",
          "name": "it_IT",
          "width": "14.0"
        },
        {
          "color": "rgb(109,247,199)",
          "height": "23.1",
          "id": "Id73",
          "language": "PHP",
          "name": "Address.php",
          "width": "23.1"
        },
        {
          "color": "rgb(109,247,203)",
          "height": "21.8",
          "id": "Id74",
          "language": "PHP",
          "name": "Person.php",
          "width": "21.8"
        },
        {
          "color": "rgb(109,247,208)",
          "height": "19.1",
          "id": "Id75",
          "language": "PHP",
          "name": "Company.php",
          "width": "19.1"
        },
        {
          "color": "rgb(109,247,212)",
          "height": "13.0",
          "id": "Id76",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "13.0"
        },
        {
          "color": "rgb(109,247,219)",
          "height": "9.2",
          "id": "Id77",
          "language": "PHP",
          "name": "Internet.php",
          "width": "9.2"
        },
        {
          "color": "rgb(109,247,224)",
          "height": "14.0",
          "id": "Id78",
          "name": "es_ES",
          "width": "14.0"
        },
        {
          "color": "rgb(109,247,228)",
          "height": "23.0",
          "id": "Id79",
          "language": "PHP",
          "name": "Address.php",
          "width": "23.0"
        },
        {
          "color": "rgb(109,247,233)",
          "height": "20.7",
          "id": "Id80",
          "language": "PHP",
          "name": "Company.php",
          "width": "20.7"
        },
        {
          "color": "rgb(109,247,238)",
          "height": "15.8",
          "id": "Id81",
          "language": "PHP",
          "name": "Person.php",
          "width": "15.8"
        },
        {
          "color": "rgb(109,247,242)",
          "height": "14.9",
          "id": "Id82",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "14.9"
        },
        {
          "color": "rgb(109,245,247)",
          "height": "14.0",
          "id": "Id83",
          "name": "en_US",
          "width": "14.0"
        },
        {
          "color": "rgb(109,240,247)",
          "height": "23.0",
          "id": "Id84",
          "language": "PHP",
          "name": "Address.php",
          "width": "23.0"
        },
        {
          "color": "rgb(109,235,247)",
          "height": "23.0",
          "id": "Id85",
          "language": "PHP",
          "name": "Person.php",
          "width": "23.0"
        },
        {
          "color": "rgb(109,231,247)",
          "height": "19.0",
          "id": "Id86",
          "language": "PHP",
          "name": "Company.php",
          "width": "19.0"
        },
        {
          "color": "rgb(109,226,247)",
          "height": "15.8",
          "id": "Id87",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "15.8"
        },
        {
          "color": "rgb(109,222,247)",
          "height": "22.9",
          "id": "Id88",
          "language": "PHP",
          "name": "Base.php",
          "width": "22.9"
        },
        {
          "color": "rgb(109,215,247)",
          "height": "14.0",
          "id": "Id89",
          "name": "es_AR",
          "width": "14.0"
        },
        {
          "color": "rgb(109,210,247)",
          "height": "22.7",
          "id": "Id90",
          "language": "PHP",
          "name": "Address.php",
          "width": "22.7"
        },
        {
          "color": "rgb(109,206,247)",
          "height": "22.4",
          "id": "Id91",
          "language": "PHP",
          "name": "Person.php",
          "width": "22.4"
        },
        {
          "color": "rgb(109,201,247)",
          "height": "19.3",
          "id": "Id92",
          "language": "PHP",
          "name": "Company.php",
          "width": "19.3"
        },
        {
          "color": "rgb(109,196,247)",
          "height": "17.5",
          "id": "Id93",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "17.5"
        },
        {
          "color": "rgb(109,192,247)",
          "height": "14.0",
          "id": "Id94",
          "name": "en_GB",
          "width": "14.0"
        },
        {
          "color": "rgb(109,187,247)",
          "height": "22.3",
          "id": "Id95",
          "language": "PHP",
          "name": "Address.php",
          "width": "22.3"
        },
        {
          "color": "rgb(109,180,247)",
          "height": "12.4",
          "id": "Id96",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "12.4"
        },
        {
          "color": "rgb(109,176,247)",
          "height": "9.2",
          "id": "Id97",
          "language": "PHP",
          "name": "Internet.php",
          "width": "9.2"
        },
        {
          "color": "rgb(109,171,247)",
          "height": "14.0",
          "id": "Id98",
          "name": "fi_FI",
          "width": "14.0"
        },
        {
          "color": "rgb(109,167,247)",
          "height": "22.0",
          "id": "Id99",
          "language": "PHP",
          "name": "Address.php",
          "width": "22.0"
        },
        {
          "color": "rgb(109,162,247)",
          "height": "21.4",
          "id": "Id100",
          "language": "PHP",
          "name": "Person.php",
          "width": "21.4"
        },
        {
          "color": "rgb(109,157,247)",
          "height": "19.0",
          "id": "Id101",
          "language": "PHP",
          "name": "Company.php",
          "width": "19.0"
        },
        {
          "color": "rgb(109,150,247)",
          "height": "12.7",
          "id": "Id102",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "12.7"
        },
        {
          "color": "rgb(109,146,247)",
          "height": "9.2",
          "id": "Id103",
          "language": "PHP",
          "name": "Internet.php",
          "width": "9.2"
        },
        {
          "color": "rgb(109,141,247)",
          "height": "21.9",
          "id": "Id104",
          "language": "PHP",
          "name": "Address.php",
          "width": "21.9"
        },
        {
          "color": "rgb(109,137,247)",
          "height": "14.0",
          "id": "Id105",
          "name": "pl_PL",
          "width": "14.0"
        },
        {
          "color": "rgb(109,132,247)",
          "height": "18.3",
          "id": "Id106",
          "language": "PHP",
          "name": "Person.php",
          "width": "18.3"
        },
        {
          "color": "rgb(109,128,247)",
          "height": "13.8",
          "id": "Id107",
          "language": "PHP",
          "name": "Internet.php",
          "width": "13.8"
        },
        {
          "color": "rgb(109,123,247)",
          "height": "10.8",
          "id": "Id108",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "10.8"
        },
        {
          "color": "rgb(109,116,247)",
          "height": "14.0",
          "id": "Id109",
          "name": "sr_Cyrl_RS",
          "width": "14.0"
        },
        {
          "color": "rgb(109,111,247)",
          "height": "17.5",
          "id": "Id110",
          "language": "PHP",
          "name": "Address.php",
          "width": "17.5"
        },
        {
          "color": "rgb(111,109,247)",
          "height": "11.5",
          "id": "Id111",
          "language": "PHP",
          "name": "Person.php",
          "width": "11.5"
        },
        {
          "color": "rgb(116,109,247)",
          "height": "14.0",
          "id": "Id112",
          "name": "sr_Latn_RS",
          "width": "14.0"
        },
        {
          "color": "rgb(121,109,247)",
          "height": "17.5",
          "id": "Id113",
          "language": "PHP",
          "name": "Address.php",
          "width": "17.5"
        },
        {
          "color": "rgb(125,109,247)",
          "height": "11.5",
          "id": "Id114",
          "language": "PHP",
          "name": "Person.php",
          "width": "11.5"
        },
        {
          "color": "rgb(132,109,247)",
          "height": "14.0",
          "id": "Id115",
          "name": "sr_RS",
          "width": "14.0"
        },
        {
          "color": "rgb(137,109,247)",
          "height": "17.5",
          "id": "Id116",
          "language": "PHP",
          "name": "Address.php",
          "width": "17.5"
        },
        {
          "color": "rgb(141,109,247)",
          "height": "11.5",
          "id": "Id117",
          "language": "PHP",
          "name": "Person.php",
          "width": "11.5"
        },
        {
          "color": "rgb(146,109,247)",
          "height": "16.6",
          "id": "Id118",
          "language": "PHP",
          "name": "Miscellaneous.php",
          "width": "16.6"
        },
        {
          "color": "rgb(150,109,247)",
          "height": "14.0",
          "id": "Id119",
          "name": "tr_TR",
          "width": "14.0"
        },
        {
          "color": "rgb(155,109,247)",
          "height": "16.0",
          "id": "Id120",
          "language": "PHP",
          "name": "Person.php",
          "width": "16.0"
        },
        {
          "color": "rgb(160,109,247)",
          "height": "9.6",
          "id": "Id121",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "9.6"
        },
        {
          "color": "rgb(167,109,247)",
          "height": "8.2",
          "id": "Id122",
          "language": "PHP",
          "name": "Internet.php",
          "width": "8.2"
        },
        {
          "color": "rgb(171,109,247)",
          "height": "15.6",
          "id": "Id123",
          "language": "PHP",
          "name": "Uuid.php",
          "width": "15.6"
        },
        {
          "color": "rgb(176,109,247)",
          "height": "14.0",
          "id": "Id124",
          "language": "PHP",
          "name": "Person.php",
          "width": "14.0"
        },
        {
          "color": "rgb(180,109,247)",
          "height": "12.7",
          "id": "Id125",
          "language": "PHP",
          "name": "Company.php",
          "width": "12.7"
        },
        {
          "color": "rgb(185,109,247)",
          "height": "10.0",
          "id": "Id126",
          "language": "PHP",
          "name": "PhoneNumber.php",
          "width": "10.0"
        },
        {
          "color": "rgb(189,109,247)",
          "height": "14.0",
          "id": "Id127",
          "name": "ORM",
          "width": "14.0"
        },
        {
          "color": "rgb(196,109,247)",
          "height": "14.0",
          "id": "Id128",
          "name": "Propel",
          "width": "14.0"
        },
        {
          "color": "rgb(201,109,247)",
          "height": "28.5",
          "id": "Id129",
          "language": "PHP",
          "name": "EntityPopulator.php",
          "width": "28.5"
        },
        {
          "color": "rgb(206,109,247)",
          "height": "21.0",
          "id": "Id130",
          "language": "PHP",
          "name": "ColumnTypeGuesser.php",
          "width": "21.0"
        },
        {
          "color": "rgb(210,109,247)",
          "height": "20.3",
          "id": "Id131",
          "language": "PHP",
          "name": "Populator.php",
          "width": "20.3"
        },
        {
          "color": "rgb(215,109,247)",
          "height": "14.0",
          "id": "Id132",
          "name": "Doctrine",
          "width": "14.0"
        },
        {
          "color": "rgb(219,109,247)",
          "height": "28.2",
          "id": "Id133",
          "language": "PHP",
          "name": "EntityPopulator.php",
          "width": "28.2"
        },
        {
          "color": "rgb(226,109,247)",
          "height": "19.4",
          "id": "Id134",
          "language": "PHP",
          "name": "Populator.php",
          "width": "19.4"
        },
        {
          "color": "rgb(231,109,247)",
          "height": "17.8",
          "id": "Id135",
          "language": "PHP",
          "name": "ColumnTypeGuesser.php",
          "width": "17.8"
        },
        {
          "color": "rgb(235,109,247)",
          "height": "14.0",
          "id": "Id136",
          "name": "Mandango",
          "width": "14.0"
        },
        {
          "color": "rgb(240,109,247)",
          "height": "23.1",
          "id": "Id137",
          "language": "PHP",
          "name": "EntityPopulator.php",
          "width": "23.1"
        },
        {
          "color": "rgb(245,109,247)",
          "height": "17.3",
          "id": "Id138",
          "language": "PHP",
          "name": "Populator.php",
          "width": "17.3"
        },
        {
          "color": "rgb(247,109,245)",
          "height": "15.6",
          "id": "Id139",
          "language": "PHP",
          "name": "ColumnTypeGuesser.php",
          "width": "15.6"
        },
        {
          "color": "rgb(247,109,240)",
          "height": "14.0",
          "id": "Id140",
          "name": "Guesser",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,233)",
          "height": "20.2",
          "id": "Id141",
          "language": "PHP",
          "name": "Name.php",
          "width": "20.2"
        },
        {
          "color": "rgb(247,109,228)",
          "height": "19.4",
          "id": "Id142",
          "language": "PHP",
          "name": "Generator.php",
          "width": "19.4"
        },
        {
          "color": "rgb(247,109,224)",
          "height": "19.0",
          "id": "Id143",
          "language": "PHP",
          "name": "Documentor.php",
          "width": "19.0"
        },
        {
          "color": "rgb(247,109,219)",
          "height": "17.0",
          "id": "Id144",
          "language": "PHP",
          "name": "Factory.php",
          "width": "17.0"
        },
        {
          "color": "rgb(247,109,215)",
          "height": "12.4",
          "id": "Id145",
          "language": "PHP",
          "name": "autoload.php",
          "width": "12.4"
        },
        {
          "color": "rgb(247,109,210)",
          "height": "14.0",
          "id": "Id146",
          "name": "test",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,203)",
          "height": "14.0",
          "id": "Id147",
          "name": "Faker",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,199)",
          "height": "25.8",
          "id": "Id148",
          "language": "PHP",
          "name": "GeneratorTest.php",
          "width": "25.8"
        },
        {
          "color": "rgb(247,109,194)",
          "height": "14.0",
          "id": "Id149",
          "name": "Provider",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,189)",
          "height": "25.3",
          "id": "Id150",
          "language": "PHP",
          "name": "BaseTest.php",
          "width": "25.3"
        },
        {
          "color": "rgb(247,109,185)",
          "height": "23.2",
          "id": "Id151",
          "language": "PHP",
          "name": "LoremTest.php",
          "width": "23.2"
        },
        {
          "color": "rgb(247,109,180)",
          "height": "14.0",
          "id": "Id152",
          "name": "fr_FR",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,176)",
          "height": "21.6",
          "id": "Id153",
          "language": "PHP",
          "name": "CompanyTest.php",
          "width": "21.6"
        },
        {
          "color": "rgb(247,109,169)",
          "height": "15.6",
          "id": "Id154",
          "language": "PHP",
          "name": "UserAgentTest.php",
          "width": "15.6"
        },
        {
          "color": "rgb(247,109,164)",
          "height": "13.5",
          "id": "Id155",
          "language": "PHP",
          "name": "PersonTest.php",
          "width": "13.5"
        },
        {
          "color": "rgb(247,109,160)",
          "height": "13.5",
          "id": "Id156",
          "language": "PHP",
          "name": "UuidTest.php",
          "width": "13.5"
        },
        {
          "color": "rgb(247,109,155)",
          "height": "11.5",
          "id": "Id157",
          "language": "PHP",
          "name": "LocalizationTest.php",
          "width": "11.5"
        },
        {
          "color": "rgb(247,109,150)",
          "height": "14.0",
          "id": "Id158",
          "name": "PHPUnit",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,146)",
          "height": "14.0",
          "id": "Id159",
          "name": "Framework",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,139)",
          "height": "14.0",
          "id": "Id160",
          "name": "Constraint",
          "width": "14.0"
        },
        {
          "color": "rgb(247,109,134)",
          "height": "14.3",
          "id": "Id161",
          "language": "PHP",
          "name": "IsValidSirenSiret.php",
          "width": "14.3"
        },
        {
          "color": "rgb(247,109,130)",
          "height": "10.4",
          "id": "Id162",
          "language": "PHP",
          "name": "IsValidSiren.php",
          "width": "10.4"
        },
        {
          "color": "rgb(247,109,125)",
          "height": "10.4",
          "id": "Id163",
          "language": "PHP",
          "name": "IsValidSiret.php",
          "width": "10.4"
        },
        {
          "color": "rgb(247,109,121)",
          "height": "17.0",
          "id": "Id164",
          "language": "PHP",
          "name": "test.php",
          "width": "17.0"
        },
        {
          "color": "rgb(247,109,116)",
          "height": "10.4",
          "id": "Id165",
          "language": "PHP",
          "name": "documentor.php",
          "width": "10.4"
        },
        {
          "color": "rgb(247,109,109)",
          "height": "6.2",
          "id": "Id166",
          "language": "YAML",
          "name": ".travis.yml",
          "width": "6.2"
        }
      ]
    },
    config = {
      "edgeColor": "rgb(158,202,225)",
      "graphType": "Network",
      "useBarnesHutSimulation": True
    },
    width = 600,
    height = 600
  )
)
